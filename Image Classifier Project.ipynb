# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
import torch
from torch import nn, optim
from torchvision import transforms, models, datasets
import torch.nn.functional as F

import json
import time
import glob
import random
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms_train = transforms.Compose([transforms.RandomRotation(15),
                                            transforms.RandomResizedCrop(224),
                                            transforms.RandomHorizontalFlip(),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.485, 0.456, 0.406],
                                                                 [0.229, 0.224, 0.225])])
# may remove the normalizers for the now????

data_transforms_valid = transforms.Compose([transforms.Resize(255),
                                            transforms.CenterCrop(224),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.485, 0.456, 0.406],
                                                                 [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=data_transforms_train)
valid_data = datasets.ImageFolder(valid_dir, transform=data_transforms_valid)
test_data = datasets.ImageFolder(test_dir, transform=data_transforms_valid)

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(dataset=train_data, batch_size=96, shuffle=True)
valid_loader = torch.utils.data.DataLoader(dataset=valid_data, batch_size=96, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_data, batch_size=96, shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)
# cat_to_name

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# Add a device mechanism
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# TODO: Build and train your network
# Load a pre-trained network
model = models.vgg11(pretrained=True)
# model

# %%
# Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# Turn off gradients
for param in model.parameters():
    param.requires_grad = False
        
model.classifier = nn.Sequential(nn.Linear(25088, 8192),
                           nn.ReLU(),
                           nn.Dropout(0.5),
                           nn.Linear(8192, 1024),
                           nn.ReLU(),
                           nn.Dropout(0.2),
                           nn.Linear(1024, 102),
                           nn.LogSoftmax(dim=1)
                          )
# model.parameters

# %%
# set criterion and optimizer
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

# Add model to device
model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=8192, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=8192, out_features=1024, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2)
#     (6): Linear(in_features=1024, out_features=102, bias=True)
#     (7): LogSoftmax()
#   )
# )

# %%
# Train the classifier layers using backpropagation using the pre-trained network to get the features
epochs = 2
train_steps = 0
train_loss = 0
iteration = 5
start_time = time.time()
for epoch in range(epochs):
    # Training loop
    for images, labels in train_loader:
        train_steps += 1
        
        # Add images and labels to device
        images, labels = images.to(device), labels.to(device)
        
        # zero gradients before each loop pass, move forward, loss, backwards, step
        optimizer.zero_grad()
        logps = model.forward(images)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        
        # Testing accurracy on validation data
        if train_steps % iteration == 0:
            valid_loss = 0
            valid_accuracy = 0
            # Place model in evaluation mode
            model.eval()
            
            # speed up by removing gradients calculations
            with torch.no_grad():                
                for images, labels in valid_loader:                
                    # Add images and labels to device
                    images, labels = images.to(device), labels.to(device)

                    # Calculating loss on validation set
                    logps_valid = model.forward(images)
                    loss = criterion(logps_valid, labels)
                    valid_loss += loss.item()

                    # Calculating accuracy on validation set
                    proba_valid = torch.exp(logps_valid)
                    top_proba, top_class = proba_valid.topk(1, dim=1)
                    equality = top_class == labels.view(*top_class.shape)
                    valid_accuracy += torch.mean(equality.type(torch.FloatTensor)).item()
                
            # Display results
            print('Epoch {}/{} ...'.format(epoch+1, epochs),
                  'Training Loss: {:3f} ...'.format(train_loss/len(train_loader)),
                  'Validation Loss: {:3f} ...'.format(valid_loss/len(valid_loader)),
                  'Validation Accuracy: {:3f} '.format(valid_accuracy/len(valid_loader))
                 )
            running_loss = 0
            model.train()  
            
print('Elapsed time: {}'.format((time.time() - start_time)//60))
# Out:
# Epoch 1/2 ... Training Loss: 0.497864 ... Validation Loss: 5.495766 ... Validation Accuracy: 0.027685
# Epoch 1/2 ... Training Loss: 0.854365 ... Validation Loss: 4.462873 ... Validation Accuracy: 0.111713
# Epoch 1/2 ... Training Loss: 1.175240 ... Validation Loss: 4.200349 ... Validation Accuracy: 0.080648
# Epoch 1/2 ... Training Loss: 1.470491 ... Validation Loss: 3.673526 ... Validation Accuracy: 0.202083
# Epoch 1/2 ... Training Loss: 1.743540 ... Validation Loss: 3.141963 ... Validation Accuracy: 0.312176
# Epoch 1/2 ... Training Loss: 1.982949 ... Validation Loss: 2.626537 ... Validation Accuracy: 0.411435
# Epoch 1/2 ... Training Loss: 2.200470 ... Validation Loss: 2.271932 ... Validation Accuracy: 0.451944
# Epoch 1/2 ... Training Loss: 2.398156 ... Validation Loss: 1.880649 ... Validation Accuracy: 0.533194
# Epoch 1/2 ... Training Loss: 2.581752 ... Validation Loss: 1.764173 ... Validation Accuracy: 0.565880
# Epoch 1/2 ... Training Loss: 2.748230 ... Validation Loss: 1.574935 ... Validation Accuracy: 0.594259
# Epoch 1/2 ... Training Loss: 2.898203 ... Validation Loss: 1.499579 ... Validation Accuracy: 0.600139
# Epoch 1/2 ... Training Loss: 3.047896 ... Validation Loss: 1.333544 ... Validation Accuracy: 0.656389
# Epoch 1/2 ... Training Loss: 3.189511 ... Validation Loss: 1.279516 ... Validation Accuracy: 0.632361
# Epoch 2/2 ... Training Loss: 3.339743 ... Validation Loss: 1.268348 ... Validation Accuracy: 0.641898
# Epoch 2/2 ... Training Loss: 3.468359 ... Validation Loss: 1.145405 ... Validation Accuracy: 0.672407
# Epoch 2/2 ... Training Loss: 3.583309 ... Validation Loss: 1.083480 ... Validation Accuracy: 0.690509
# Epoch 2/2 ... Training Loss: 3.697711 ... Validation Loss: 1.057789 ... Validation Accuracy: 0.715787
# Epoch 2/2 ... Training Loss: 3.808434 ... Validation Loss: 0.899526 ... Validation Accuracy: 0.741852
# Epoch 2/2 ... Training Loss: 3.920615 ... Validation Loss: 0.905214 ... Validation Accuracy: 0.757778
# Epoch 2/2 ... Training Loss: 4.031859 ... Validation Loss: 0.890788 ... Validation Accuracy: 0.759398
# Epoch 2/2 ... Training Loss: 4.139088 ... Validation Loss: 0.827556 ... Validation Accuracy: 0.778796
# Epoch 2/2 ... Training Loss: 4.245231 ... Validation Loss: 0.760500 ... Validation Accuracy: 0.799259
# Epoch 2/2 ... Training Loss: 4.338439 ... Validation Loss: 0.714710 ... Validation Accuracy: 0.800231
# Epoch 2/2 ... Training Loss: 4.450565 ... Validation Loss: 0.745666 ... Validation Accuracy: 0.770972
# Epoch 2/2 ... Training Loss: 4.554649 ... Validation Loss: 0.764225 ... Validation Accuracy: 0.802917
# Epoch 2/2 ... Training Loss: 4.667837 ... Validation Loss: 0.721258 ... Validation Accuracy: 0.803194
# Epoch 2/2 ... Training Loss: 4.765366 ... Validation Loss: 0.702376 ... Validation Accuracy: 0.803009
# Elapsed time: 9.0

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
test_loss = 0
test_accuracy = 0
# Place model in evaluation mode
model.eval()
            
# speed up by removing gradients calculations
with torch.no_grad():                
    for images, labels in test_loader:                
        # Add images and labels to device
        images, labels = images.to(device), labels.to(device)

        # Calculating loss on validation set
        logps_test = model(images)
        loss = criterion(logps_test, labels)
        test_loss += loss.item()

        # Calculating accuracy on validation set
        proba_test = torch.exp(logps_test)
        top_proba, top_class = proba_test.topk(1, dim=1)
        equality = top_class == labels.view(*top_class.shape)
        test_accuracy += torch.mean(equality.type(torch.FloatTensor)).item()

# Display results
print('Test Loss: {:3f} ...'.format(test_loss/len(test_loader)),
      'Test Accuracy: {:3f} '.format(test_accuracy/len(test_loader))
     )
print('Elapsed time: {}'.format((time.time() - start_time)//60))
# Out:
# Test Loss: 0.777812 ... Test Accuracy: 0.789011
# Elapsed time: 9.0

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
# add checkpoint information
checkpoint = {'classifier': model.classifier,
              'state_dict': model.state_dict(),
              'class_to_idx': train_data.class_to_idx
             }

torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(path):
    # ensure the model is loaded by GPU even if the GPU is off (SO)
    if torch.cuda.is_available():
        map_location = lambda storage, loc: storage.cuda()
    else:
        map_location = 'cpu'
    checkpoint = torch.load(path, map_location=map_location)
    model = models.vgg11(pretrained=True)
    model.classifier = checkpoint['classifier']
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    
    for param in model.parameters():
        param.requires_grad = False
    
    return model

# %%
model = load_checkpoint('checkpoint.pth')
model.parameters
# Out:
# <bound method Module.parameters of VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=8192, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=8192, out_features=1024, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2)
#     (6): Linear(in_features=1024, out_features=102, bias=True)
#     (7): LogSoftmax()
#   )
# )>

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image_path):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    # could also have used transforms here. 
    # feel it would be a better approach even
    # get the image, size
    img = Image.open(image_path)
    width, height = img.size
    
    # resize the image to 256 
    if width < height:
        n_height = int(256*(height/width))
        img = img.resize((256, n_height))
    else:
        n_width = int(256*(width/height))
        img = img.resize((n_width, 256))
        
    # center crop image
    # don't really understand these implementation
    c_width, c_height = 224, 224
    c_left = int((img.width - c_width)/2) 
    c_top = int((img.height - c_height)/2) 
    c_right = int((img.width - c_width)/2 + c_width) 
    c_bottom = int((img.height - c_height)/2 + c_height)
    img = img.crop((c_left, c_top, c_right, c_bottom))
    
    # convert image to array    
    np_img = np.array(img)
    
    # normalize RGB values in range 0:1
    # divide all values by 255
    np_img = np_img/255
    mu = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    # normalize by subtracting mu from each color channel & divide by std
    np_img = (np_img - mu)/std
    # transpose the order so that the color channel is now at the 1st index
    np_img = np_img.transpose((2, 0, 1)) 
    
    # convert processed image into a tensor
    tensor_img = torch.from_numpy(np_img)
        
    return tensor_img
#     return np_img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
img = random.choice(glob.glob('flowers/test/*/*.jpg'))
imshow(process_image(img));

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    # loads the checkpoint model
    model = load_checkpoint('checkpoint.pth')
    model.to(device)            
    model.eval()                # evaluation mode
    img = image_path.unsqueeze(0).float()
    
    with torch.no_grad():
        ps = model(img)
    proba = F.softmax(ps.data, dim=1)      # use Functional and softmax to do the hard lifting
        
    return proba.topk(topk)

# %%
img = random.choice(glob.glob('flowers/test/*/*.jpg'))
processed_img = process_image(img)
model = load_checkpoint('checkpoint.pth')
processed_img = processed_img.to(device)
proba, classes = predict(processed_img, model, topk=5)
print(proba)
print(classes)
# Out:
# tensor([[ 0.9996,  0.0002,  0.0000,  0.0000,  0.0000]], device='cuda:0')
# tensor([[ 54,  63,  57,  47,  64]], device='cuda:0')

# %%
np_proba = proba.to('cpu').numpy().squeeze()
np_classes = classes.to('cpu').numpy().squeeze()

print(np_proba)
print(type(np_proba))

print(np_classes)
print(type(np_classes))
# Out:
# [  9.99600828e-01   1.76489732e-04   4.28429776e-05   3.28295610e-05
#    2.85409642e-05]
# <class 'numpy.ndarray'>
# [54 63 57 47 64]
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
img = random.choice(glob.glob('flowers/test/*/*.jpg'))
processed_img = process_image(img)

flower_number = img.split('/')[2]
flower_name = cat_to_name[flower_number]

# show the image
ax1 = plt.subplot(2,1,1)
ax1.axis('off')
ax1.set_title(flower_name)

imshow(processed_img, ax1, flower_name)

# load model and predict image 
model = load_checkpoint('checkpoint.pth')

# add processed_image to device
processed_img = processed_img.to(device)

# get top predictions and labels
proba, labels = predict(processed_img, model)

# transfer to CPU and convert to numpy arrays
proba = proba.to('cpu').numpy().squeeze()
labels = labels.to('cpu').numpy().squeeze()

# Convert to classes
idx_to_class = {val: key for key, val in model.class_to_idx.items()}
labels = [idx_to_class[i] for i in labels]
flowers = [cat_to_name[i] for i in labels]

y_pos = np.arange(len(flowers))

ax2 = plt.subplot(2,1,2)
ax2.set_yticks(y_pos)
ax2.set_yticklabels(flowers)
plt.barh(y_pos, proba)
plt.show();

# %%
# !tar chvfz image_classifier.tar.gz *
# Out:
# Image Classifier Project-zh.ipynb
# Image Classifier Project.ipynb
# LICENSE
# README.md
# assets/
# assets/inference_example.png
# assets/Flowers.png
# cat_to_name.json
# checkpoint.pth
# flowers/
# flowers/train/
# flowers/train/43/
# flowers/train/43/image_02347.jpg
# flowers/train/43/image_02420.jpg
# flowers/train/43/image_02350.jpg
# flowers/train/43/image_02387.jpg
# flowers/train/43/image_02322.jpg
# flowers/train/43/image_02344.jpg
# flowers/train/43/image_02378.jpg
# flowers/train/43/image_02398.jpg
# flowers/train/43/image_02379.jpg
# flowers/train/43/image_02339.jpg
# flowers/train/43/image_02343.jpg
# flowers/train/43/image_02432.jpg
# flowers/train/43/image_02395.jpg
# flowers/train/43/image_02417.jpg
# flowers/train/43/image_02393.jpg
# flowers/train/43/image_02361.jpg
# flowers/train/43/image_02406.jpg
# flowers/train/43/image_02356.jpg
# flowers/train/43/image_02399.jpg
# flowers/train/43/image_02413.jpg
# flowers/train/43/image_02332.jpg
# flowers/train/43/image_02409.jpg
# flowers/train/43/image_02333.jpg
# flowers/train/43/image_02436.jpg
# flowers/train/43/image_02316.jpg
# flowers/train/43/image_02403.jpg
# flowers/train/43/image_02390.jpg
# flowers/train/43/image_02404.jpg
# flowers/train/43/image_02324.jpg
# flowers/train/43/image_02405.jpg
# flowers/train/43/image_02445.jpg
# flowers/train/43/image_02377.jpg
# flowers/train/43/image_02380.jpg
# flowers/train/43/image_02438.jpg
# flowers/train/43/image_02374.jpg
# flowers/train/43/image_02367.jpg
# flowers/train/43/image_02430.jpg
# flowers/train/43/image_02411.jpg
# flowers/train/43/image_02402.jpg
# flowers/train/43/image_02321.jpg
# flowers/train/43/image_02359.jpg
# flowers/train/43/image_02410.jpg
# flowers/train/43/image_02418.jpg
# flowers/train/43/image_02325.jpg
# flowers/train/43/image_02348.jpg
# flowers/train/43/image_02388.jpg
# flowers/train/43/image_02354.jpg
# flowers/train/43/image_02444.jpg
# flowers/train/43/image_02434.jpg
# flowers/train/43/image_02342.jpg
# flowers/train/43/image_02363.jpg
# flowers/train/43/image_02442.jpg
# flowers/train/43/image_02428.jpg
# flowers/train/43/image_02427.jpg
# flowers/train/43/image_02357.jpg
# flowers/train/43/image_02341.jpg
# flowers/train/43/image_02372.jpg
# flowers/train/43/image_02319.jpg
# flowers/train/43/image_02360.jpg
# flowers/train/43/image_02416.jpg
# flowers/train/43/image_02366.jpg
# flowers/train/43/image_02337.jpg
# flowers/train/43/image_02317.jpg
# flowers/train/43/image_02381.jpg
# flowers/train/43/image_02437.jpg
# flowers/train/43/image_02352.jpg
# flowers/train/43/image_02422.jpg
# flowers/train/43/image_02353.jpg
# flowers/train/43/image_02318.jpg
# flowers/train/43/image_02327.jpg
# flowers/train/43/image_02439.jpg
# flowers/train/43/image_02331.jpg
# flowers/train/43/image_02383.jpg
# flowers/train/43/image_02364.jpg
# flowers/train/43/image_02328.jpg
# flowers/train/43/image_02351.jpg
# flowers/train/43/image_02376.jpg
# flowers/train/43/image_02391.jpg
# flowers/train/43/image_02362.jpg
# flowers/train/43/image_02373.jpg
# flowers/train/43/image_02384.jpg
# flowers/train/43/image_02375.jpg
# flowers/train/43/image_02396.jpg
# flowers/train/43/image_02340.jpg
# flowers/train/43/image_02326.jpg
# flowers/train/43/image_02441.jpg
# flowers/train/43/image_02415.jpg
# flowers/train/43/image_02323.jpg
# flowers/train/43/image_02338.jpg
# flowers/train/43/image_02423.jpg
# flowers/train/43/image_02408.jpg
# flowers/train/43/image_02392.jpg
# flowers/train/43/image_02358.jpg
# flowers/train/43/image_02440.jpg
# flowers/train/43/image_02424.jpg
# flowers/train/43/image_02385.jpg
# flowers/train/43/image_02320.jpg
# flowers/train/43/image_02401.jpg
# flowers/train/43/image_02382.jpg
# flowers/train/43/image_02334.jpg
# flowers/train/92/
# flowers/train/92/image_03070.jpg
# flowers/train/92/image_03073.jpg
# flowers/train/92/image_03090.jpg
# flowers/train/92/image_03055.jpg
# flowers/train/92/image_03074.jpg
# flowers/train/92/image_03050.jpg
# flowers/train/92/image_03035.jpg
# flowers/train/92/image_03091.jpg
# flowers/train/92/image_03071.jpg
# flowers/train/92/image_03081.jpg
# flowers/train/92/image_03034.jpg
# flowers/train/92/image_03045.jpg
# flowers/train/92/image_03064.jpg
# flowers/train/92/image_03085.jpg
# flowers/train/92/image_03079.jpg
# flowers/train/92/image_03076.jpg
# flowers/train/92/image_03047.jpg
# flowers/train/92/image_03060.jpg
# flowers/train/92/image_03093.jpg
# flowers/train/92/image_03046.jpg
# flowers/train/92/image_03080.jpg
# flowers/train/92/image_03086.jpg
# flowers/train/92/image_03094.jpg
# flowers/train/92/image_03088.jpg
# flowers/train/92/image_03051.jpg
# flowers/train/92/image_03038.jpg
# flowers/train/92/image_03066.jpg
# flowers/train/92/image_03042.jpg
# flowers/train/92/image_03069.jpg
# flowers/train/92/image_03084.jpg
# flowers/train/92/image_03078.jpg
# flowers/train/92/image_03036.jpg
# flowers/train/92/image_03033.jpg
# flowers/train/92/image_03030.jpg
# flowers/train/92/image_03029.jpg
# flowers/train/92/image_03083.jpg
# flowers/train/92/image_03092.jpg
# flowers/train/92/image_03067.jpg
# flowers/train/92/image_03043.jpg
# flowers/train/92/image_03077.jpg
# flowers/train/92/image_03053.jpg
# flowers/train/92/image_03061.jpg
# flowers/train/92/image_03062.jpg
# flowers/train/92/image_03057.jpg
# flowers/train/92/image_03059.jpg
# flowers/train/92/image_03031.jpg
# flowers/train/92/image_03037.jpg
# flowers/train/92/image_03089.jpg
# flowers/train/92/image_03072.jpg
# flowers/train/92/image_03040.jpg
# flowers/train/92/image_03068.jpg
# flowers/train/92/image_03082.jpg
# flowers/train/92/image_03087.jpg
# flowers/train/88/
# flowers/train/88/image_00519.jpg
# flowers/train/88/image_00586.jpg
# flowers/train/88/image_00449.jpg
# flowers/train/88/image_00491.jpg
# flowers/train/88/image_00559.jpg
# flowers/train/88/image_00460.jpg
# flowers/train/88/image_00575.jpg
# flowers/train/88/image_00562.jpg
# flowers/train/88/image_00570.jpg
# flowers/train/88/image_00553.jpg
# flowers/train/88/image_00462.jpg
# flowers/train/88/image_00471.jpg
# flowers/train/88/image_00454.jpg
# flowers/train/88/image_00499.jpg
# flowers/train/88/image_00558.jpg
# flowers/train/88/image_00455.jpg
# flowers/train/88/image_00527.jpg
# flowers/train/88/image_00537.jpg
# flowers/train/88/image_00576.jpg
# flowers/train/88/image_00529.jpg
# flowers/train/88/image_00592.jpg
# flowers/train/88/image_00564.jpg
# flowers/train/88/image_00504.jpg
# flowers/train/88/image_00496.jpg
# flowers/train/88/image_00535.jpg
# flowers/train/88/image_00522.jpg
# flowers/train/88/image_00524.jpg
# flowers/train/88/image_00463.jpg
# flowers/train/88/image_00475.jpg
# flowers/train/88/image_00536.jpg
# flowers/train/88/image_00530.jpg
# flowers/train/88/image_00458.jpg
# flowers/train/88/image_00581.jpg
# flowers/train/88/image_00451.jpg
# flowers/train/88/image_00466.jpg
# flowers/train/88/image_00448.jpg
# flowers/train/88/image_00587.jpg
# flowers/train/88/image_00468.jpg
# flowers/train/88/image_00528.jpg
# flowers/train/88/image_00473.jpg
# flowers/train/88/image_00552.jpg
# flowers/train/88/image_00465.jpg
# flowers/train/88/image_00488.jpg
# flowers/train/88/image_00472.jpg
# flowers/train/88/image_00501.jpg
# flowers/train/88/image_00481.jpg
# flowers/train/88/image_00566.jpg
# flowers/train/88/image_00498.jpg
# flowers/train/88/image_00579.jpg
# flowers/train/88/image_00532.jpg
# flowers/train/88/image_00560.jpg
# flowers/train/88/image_00538.jpg
# flowers/train/88/image_00514.jpg
# flowers/train/88/image_00479.jpg
# flowers/train/88/image_00510.jpg
# flowers/train/88/image_00478.jpg
# flowers/train/88/image_00483.jpg
# flowers/train/88/image_00492.jpg
# flowers/train/88/image_08082.jpg
# flowers/train/88/image_00495.jpg
# flowers/train/88/image_00453.jpg
# flowers/train/88/image_00452.jpg
# flowers/train/88/image_00565.jpg
# flowers/train/88/image_00485.jpg
# flowers/train/88/image_00507.jpg
# flowers/train/88/image_00534.jpg
# flowers/train/88/image_00580.jpg
# flowers/train/88/image_00548.jpg
# flowers/train/88/image_00450.jpg
# flowers/train/88/image_00541.jpg
# flowers/train/88/image_00464.jpg
# flowers/train/88/image_00490.jpg
# flowers/train/88/image_00591.jpg
# flowers/train/88/image_00517.jpg
# flowers/train/88/image_00525.jpg
# flowers/train/88/image_00447.jpg
# flowers/train/88/image_00480.jpg
# flowers/train/88/image_00549.jpg
# flowers/train/88/image_00567.jpg
# flowers/train/88/image_00588.jpg
# flowers/train/88/image_00446.jpg
# flowers/train/88/image_00590.jpg
# flowers/train/88/image_00571.jpg
# flowers/train/88/image_00513.jpg
# flowers/train/88/image_00543.jpg
# flowers/train/88/image_00470.jpg
# flowers/train/88/image_00500.jpg
# flowers/train/88/image_00573.jpg
# flowers/train/88/image_00568.jpg
# flowers/train/88/image_00469.jpg
# flowers/train/88/image_00555.jpg
# flowers/train/88/image_00486.jpg
# flowers/train/88/image_00493.jpg
# flowers/train/88/image_00497.jpg
# flowers/train/88/image_00596.jpg
# flowers/train/88/image_00503.jpg
# flowers/train/88/image_00487.jpg
# flowers/train/88/image_00521.jpg
# flowers/train/88/image_00456.jpg
# flowers/train/88/image_00523.jpg
# flowers/train/88/image_08083.jpg
# flowers/train/88/image_00515.jpg
# flowers/train/88/image_00583.jpg
# flowers/train/88/image_00506.jpg
# flowers/train/88/image_00494.jpg
# flowers/train/88/image_00505.jpg
# flowers/train/88/image_00561.jpg
# flowers/train/88/image_00550.jpg
# flowers/train/88/image_00578.jpg
# flowers/train/88/image_00484.jpg
# flowers/train/88/image_00572.jpg
# flowers/train/88/image_00569.jpg
# flowers/train/88/image_00476.jpg
# flowers/train/88/image_00511.jpg
# flowers/train/88/image_00557.jpg
# flowers/train/88/image_00589.jpg
# flowers/train/91/
# flowers/train/91/image_04893.jpg
# flowers/train/91/image_04836.jpg
# flowers/train/91/image_04886.jpg
# flowers/train/91/image_04852.jpg
# flowers/train/91/image_04849.jpg
# flowers/train/91/image_04871.jpg
# flowers/train/91/image_04865.jpg
# flowers/train/91/image_08058.jpg
# flowers/train/91/image_04894.jpg
# flowers/train/91/image_04846.jpg
# flowers/train/91/image_04895.jpg
# flowers/train/91/image_04855.jpg
# flowers/train/91/image_08060.jpg
# flowers/train/91/image_08056.jpg
# flowers/train/91/image_04831.jpg
# flowers/train/91/image_04845.jpg
# flowers/train/91/image_04861.jpg
# flowers/train/91/image_04891.jpg
# flowers/train/91/image_04869.jpg
# flowers/train/91/image_04834.jpg
# flowers/train/91/image_04884.jpg
# flowers/train/91/image_04853.jpg
# flowers/train/91/image_04832.jpg
# flowers/train/91/image_04882.jpg
# flowers/train/91/image_04896.jpg
# flowers/train/91/image_04885.jpg
# flowers/train/91/image_04857.jpg
# flowers/train/91/image_04837.jpg
# flowers/train/91/image_04874.jpg
# flowers/train/91/image_04876.jpg
# flowers/train/91/image_04888.jpg
# flowers/train/91/image_04877.jpg
# flowers/train/91/image_04867.jpg
# flowers/train/91/image_04881.jpg
# flowers/train/91/image_08055.jpg
# flowers/train/91/image_08057.jpg
# flowers/train/91/image_04880.jpg
# flowers/train/91/image_04840.jpg
# flowers/train/91/image_04879.jpg
# flowers/train/91/image_04847.jpg
# flowers/train/91/image_04892.jpg
# flowers/train/91/image_04841.jpg
# flowers/train/91/image_04887.jpg
# flowers/train/91/image_04863.jpg
# flowers/train/91/image_04842.jpg
# flowers/train/91/image_04833.jpg
# flowers/train/91/image_04868.jpg
# flowers/train/91/image_04864.jpg
# flowers/train/91/image_04889.jpg
# flowers/train/91/image_04859.jpg
# flowers/train/91/image_04858.jpg
# flowers/train/91/image_04866.jpg
# flowers/train/91/image_04838.jpg
# flowers/train/91/image_04850.jpg
# flowers/train/91/image_04862.jpg
# flowers/train/91/image_08054.jpg
# flowers/train/91/image_04830.jpg
# flowers/train/91/image_04839.jpg
# flowers/train/91/image_04873.jpg
# flowers/train/95/
# flowers/train/95/image_07499.jpg
# flowers/train/95/image_07497.jpg
# flowers/train/95/image_07531.jpg
# flowers/train/95/image_07488.jpg
# flowers/train/95/image_07534.jpg
# flowers/train/95/image_07537.jpg
# flowers/train/95/image_07553.jpg
# flowers/train/95/image_07479.jpg
# flowers/train/95/image_07526.jpg
# flowers/train/95/image_07540.jpg
# flowers/train/95/image_07495.jpg
# flowers/train/95/image_07528.jpg
# flowers/train/95/image_07560.jpg
# flowers/train/95/image_07496.jpg
# flowers/train/95/image_07544.jpg
# flowers/train/95/image_07582.jpg
# flowers/train/95/image_07566.jpg
# flowers/train/95/image_07516.jpg
# flowers/train/95/image_07474.jpg
# flowers/train/95/image_07577.jpg
# flowers/train/95/image_07522.jpg
# flowers/train/95/image_07525.jpg
# flowers/train/95/image_07541.jpg
# flowers/train/95/image_07533.jpg
# flowers/train/95/image_07593.jpg
# flowers/train/95/image_07547.jpg
# flowers/train/95/image_07543.jpg
# flowers/train/95/image_07483.jpg
# flowers/train/95/image_07546.jpg
# flowers/train/95/image_07524.jpg
# flowers/train/95/image_07477.jpg
# flowers/train/95/image_07511.jpg
# flowers/train/95/image_07532.jpg
# flowers/train/95/image_07591.jpg
# flowers/train/95/image_07492.jpg
# flowers/train/95/image_07579.jpg
# flowers/train/95/image_07473.jpg
# flowers/train/95/image_07466.jpg
# flowers/train/95/image_07494.jpg
# flowers/train/95/image_07501.jpg
# flowers/train/95/image_07570.jpg
# flowers/train/95/image_07515.jpg
# flowers/train/95/image_07480.jpg
# flowers/train/95/image_07590.jpg
# flowers/train/95/image_07564.jpg
# flowers/train/95/image_07589.jpg
# flowers/train/95/image_07554.jpg
# flowers/train/95/image_07557.jpg
# flowers/train/95/image_07518.jpg
# flowers/train/95/image_07556.jpg
# flowers/train/95/image_07530.jpg
# flowers/train/95/image_07476.jpg
# flowers/train/95/image_07535.jpg
# flowers/train/95/image_07500.jpg
# flowers/train/95/image_07539.jpg
# flowers/train/95/image_07482.jpg
# flowers/train/95/image_07506.jpg
# flowers/train/95/image_07478.jpg
# flowers/train/95/image_07576.jpg
# flowers/train/95/image_07538.jpg
# flowers/train/95/image_07467.jpg
# flowers/train/95/image_07509.jpg
# flowers/train/95/image_07521.jpg
# flowers/train/95/image_07587.jpg
# flowers/train/95/image_07574.jpg
# flowers/train/95/image_07503.jpg
# flowers/train/95/image_07568.jpg
# flowers/train/95/image_07569.jpg
# flowers/train/95/image_07481.jpg
# flowers/train/95/image_07578.jpg
# flowers/train/95/image_07571.jpg
# flowers/train/95/image_07559.jpg
# flowers/train/95/image_07563.jpg
# flowers/train/95/image_07523.jpg
# flowers/train/95/image_07469.jpg
# flowers/train/95/image_07592.jpg
# flowers/train/95/image_07517.jpg
# flowers/train/95/image_07548.jpg
# flowers/train/95/image_07498.jpg
# flowers/train/95/image_07504.jpg
# flowers/train/95/image_07583.jpg
# flowers/train/95/image_07542.jpg
# flowers/train/95/image_07489.jpg
# flowers/train/95/image_07567.jpg
# flowers/train/95/image_07572.jpg
# flowers/train/95/image_07545.jpg
# flowers/train/95/image_07552.jpg
# flowers/train/95/image_07565.jpg
# flowers/train/95/image_07555.jpg
# flowers/train/95/image_07586.jpg
# flowers/train/95/image_07490.jpg
# flowers/train/95/image_07491.jpg
# flowers/train/95/image_07493.jpg
# flowers/train/95/image_07486.jpg
# flowers/train/95/image_07549.jpg
# flowers/train/95/image_07558.jpg
# flowers/train/95/image_07529.jpg
# flowers/train/95/image_07520.jpg
# flowers/train/95/image_07507.jpg
# flowers/train/95/image_07527.jpg
# flowers/train/95/image_07562.jpg
# flowers/train/29/
# flowers/train/29/image_04154.jpg
# flowers/train/29/image_04149.jpg
# flowers/train/29/image_04121.jpg
# flowers/train/29/image_04144.jpg
# flowers/train/29/image_04107.jpg
# flowers/train/29/image_04088.jpg
# flowers/train/29/image_04091.jpg
# flowers/train/29/image_04126.jpg
# flowers/train/29/image_04102.jpg
# flowers/train/29/image_04081.jpg
# flowers/train/29/image_04094.jpg
# flowers/train/29/image_04084.jpg
# flowers/train/29/image_04087.jpg
# flowers/train/29/image_04119.jpg
# flowers/train/29/image_04111.jpg
# flowers/train/29/image_04092.jpg
# flowers/train/29/image_04138.jpg
# flowers/train/29/image_04125.jpg
# flowers/train/29/image_04123.jpg
# flowers/train/29/image_04129.jpg
# flowers/train/29/image_04152.jpg
# flowers/train/29/image_04132.jpg
# flowers/train/29/image_04131.jpg
# flowers/train/29/image_04130.jpg
# flowers/train/29/image_04118.jpg
# flowers/train/29/image_04153.jpg
# flowers/train/29/image_04113.jpg
# flowers/train/29/image_04117.jpg
# flowers/train/29/image_04158.jpg
# flowers/train/29/image_04140.jpg
# flowers/train/29/image_04093.jpg
# flowers/train/29/image_04100.jpg
# flowers/train/29/image_04122.jpg
# flowers/train/29/image_04089.jpg
# flowers/train/29/image_04105.jpg
# flowers/train/29/image_04096.jpg
# flowers/train/29/image_04098.jpg
# flowers/train/29/image_04086.jpg
# flowers/train/29/image_04133.jpg
# flowers/train/29/image_04148.jpg
# flowers/train/29/image_04147.jpg
# flowers/train/29/image_04128.jpg
# flowers/train/29/image_04136.jpg
# flowers/train/29/image_04082.jpg
# flowers/train/29/image_04135.jpg
# flowers/train/29/image_04134.jpg
# flowers/train/29/image_04157.jpg
# flowers/train/29/image_04141.jpg
# flowers/train/29/image_04151.jpg
# flowers/train/29/image_04109.jpg
# flowers/train/29/image_04155.jpg
# flowers/train/29/image_04127.jpg
# flowers/train/29/image_04114.jpg
# flowers/train/29/image_04106.jpg
# flowers/train/29/image_04085.jpg
# flowers/train/29/image_04101.jpg
# flowers/train/29/image_04115.jpg
# flowers/train/29/image_04120.jpg
# flowers/train/29/image_04156.jpg
# flowers/train/29/image_04110.jpg
# flowers/train/29/image_04150.jpg
# flowers/train/29/image_04139.jpg
# flowers/train/19/
# flowers/train/19/image_06181.jpg
# flowers/train/19/image_06194.jpg
# flowers/train/19/image_06183.jpg
# flowers/train/19/image_06164.jpg
# flowers/train/19/image_06172.jpg
# flowers/train/19/image_06162.jpg
# flowers/train/19/image_06191.jpg
# flowers/train/19/image_06163.jpg
# flowers/train/19/image_06176.jpg
# flowers/train/19/image_06179.jpg
# flowers/train/19/image_06173.jpg
# flowers/train/19/image_06177.jpg
# flowers/train/19/image_06184.jpg
# flowers/train/19/image_06189.jpg
# flowers/train/19/image_06171.jpg
# flowers/train/19/image_06151.jpg
# flowers/train/19/image_06190.jpg
# flowers/train/19/image_06180.jpg
# flowers/train/19/image_06174.jpg
# flowers/train/19/image_06153.jpg
# flowers/train/19/image_06169.jpg
# flowers/train/19/image_06192.jpg
# flowers/train/19/image_06182.jpg
# flowers/train/19/image_06178.jpg
# flowers/train/19/image_06157.jpg
# flowers/train/19/image_06188.jpg
# flowers/train/19/image_06152.jpg
# flowers/train/19/image_06168.jpg
# flowers/train/19/image_06185.jpg
# flowers/train/19/image_06161.jpg
# flowers/train/19/image_06160.jpg
# flowers/train/19/image_06193.jpg
# flowers/train/19/image_06167.jpg
# flowers/train/19/image_06156.jpg
# flowers/train/19/image_06166.jpg
# flowers/train/19/image_06154.jpg
# flowers/train/19/image_06149.jpg
# flowers/train/19/image_06150.jpg
# flowers/train/85/
# flowers/train/85/image_04821.jpg
# flowers/train/85/image_04802.jpg
# flowers/train/85/image_04788.jpg
# flowers/train/85/image_04792.jpg
# flowers/train/85/image_04796.jpg
# flowers/train/85/image_04769.jpg
# flowers/train/85/image_04778.jpg
# flowers/train/85/image_04794.jpg
# flowers/train/85/image_04773.jpg
# flowers/train/85/image_04771.jpg
# flowers/train/85/image_04803.jpg
# flowers/train/85/image_04807.jpg
# flowers/train/85/image_04775.jpg
# flowers/train/85/image_04828.jpg
# flowers/train/85/image_04779.jpg
# flowers/train/85/image_04795.jpg
# flowers/train/85/image_04770.jpg
# flowers/train/85/image_04827.jpg
# flowers/train/85/image_04822.jpg
# flowers/train/85/image_04789.jpg
# flowers/train/85/image_04782.jpg
# flowers/train/85/image_04774.jpg
# flowers/train/85/image_04793.jpg
# flowers/train/85/image_04800.jpg
# flowers/train/85/image_04823.jpg
# flowers/train/85/image_04798.jpg
# flowers/train/85/image_04783.jpg
# flowers/train/85/image_04811.jpg
# flowers/train/85/image_04790.jpg
# flowers/train/85/image_04772.jpg
# flowers/train/85/image_04768.jpg
# flowers/train/85/image_04777.jpg
# flowers/train/85/image_04791.jpg
# flowers/train/85/image_04816.jpg
# flowers/train/85/image_04780.jpg
# flowers/train/85/image_04813.jpg
# flowers/train/85/image_04781.jpg
# flowers/train/85/image_04785.jpg
# flowers/train/85/image_04784.jpg
# flowers/train/85/image_04776.jpg
# flowers/train/85/image_04767.jpg
# flowers/train/85/image_04826.jpg
# flowers/train/85/image_04820.jpg
# flowers/train/85/image_04815.jpg
# flowers/train/85/image_04824.jpg
# flowers/train/85/image_04812.jpg
# flowers/train/85/image_07301.jpg
# flowers/train/85/image_04787.jpg
# flowers/train/9/
# flowers/train/9/image_06400.jpg
# flowers/train/9/image_06430.jpg
# flowers/train/9/image_06402.jpg
# flowers/train/9/image_06438.jpg
# flowers/train/9/image_06416.jpg
# flowers/train/9/image_06399.jpg
# flowers/train/9/image_06426.jpg
# flowers/train/9/image_06421.jpg
# flowers/train/9/image_06409.jpg
# flowers/train/9/image_06422.jpg
# flowers/train/9/image_06432.jpg
# flowers/train/9/image_06424.jpg
# flowers/train/9/image_06415.jpg
# flowers/train/9/image_06395.jpg
# flowers/train/9/image_06418.jpg
# flowers/train/9/image_06436.jpg
# flowers/train/9/image_06437.jpg
# flowers/train/9/image_06407.jpg
# flowers/train/9/image_06429.jpg
# flowers/train/9/image_06411.jpg
# flowers/train/9/image_06439.jpg
# flowers/train/9/image_06419.jpg
# flowers/train/9/image_06408.jpg
# flowers/train/9/image_06401.jpg
# flowers/train/9/image_06397.jpg
# flowers/train/9/image_06433.jpg
# flowers/train/9/image_06405.jpg
# flowers/train/9/image_06435.jpg
# flowers/train/9/image_06434.jpg
# flowers/train/9/image_06423.jpg
# flowers/train/9/image_06412.jpg
# flowers/train/9/image_06427.jpg
# flowers/train/9/image_06404.jpg
# flowers/train/9/image_06425.jpg
# flowers/train/9/image_06406.jpg
# flowers/train/9/image_06417.jpg
# flowers/train/9/image_06431.jpg
# flowers/train/9/image_06396.jpg
# flowers/train/9/image_06403.jpg
# flowers/train/9/image_06428.jpg
# flowers/train/9/image_06440.jpg
# flowers/train/74/
# flowers/train/74/image_01248.jpg
# flowers/train/74/image_01311.jpg
# flowers/train/74/image_01218.jpg
# flowers/train/74/image_01183.jpg
# flowers/train/74/image_01189.jpg
# flowers/train/74/image_01284.jpg
# flowers/train/74/image_01167.jpg
# flowers/train/74/image_01293.jpg
# flowers/train/74/image_01257.jpg
# flowers/train/74/image_01302.jpg
# flowers/train/74/image_01229.jpg
# flowers/train/74/image_01238.jpg
# flowers/train/74/image_01176.jpg
# flowers/train/74/image_01296.jpg
# flowers/train/74/image_01269.jpg
# flowers/train/74/image_01186.jpg
# flowers/train/74/image_01221.jpg
# flowers/train/74/image_01148.jpg
# flowers/train/74/image_01150.jpg
# flowers/train/74/image_01235.jpg
# flowers/train/74/image_01289.jpg
# flowers/train/74/image_01169.jpg
# flowers/train/74/image_01158.jpg
# flowers/train/74/image_01247.jpg
# flowers/train/74/image_01301.jpg
# flowers/train/74/image_01252.jpg
# flowers/train/74/image_01204.jpg
# flowers/train/74/image_01152.jpg
# flowers/train/74/image_01227.jpg
# flowers/train/74/image_01243.jpg
# flowers/train/74/image_01231.jpg
# flowers/train/74/image_01146.jpg
# flowers/train/74/image_01172.jpg
# flowers/train/74/image_01155.jpg
# flowers/train/74/image_01160.jpg
# flowers/train/74/image_01241.jpg
# flowers/train/74/image_01304.jpg
# flowers/train/74/image_01262.jpg
# flowers/train/74/image_01275.jpg
# flowers/train/74/image_01279.jpg
# flowers/train/74/image_01202.jpg
# flowers/train/74/image_01178.jpg
# flowers/train/74/image_01220.jpg
# flowers/train/74/image_01237.jpg
# flowers/train/74/image_01246.jpg
# flowers/train/74/image_01177.jpg
# flowers/train/74/image_01185.jpg
# flowers/train/74/image_01258.jpg
# flowers/train/74/image_01308.jpg
# flowers/train/74/image_01166.jpg
# flowers/train/74/image_01198.jpg
# flowers/train/74/image_01161.jpg
# flowers/train/74/image_01265.jpg
# flowers/train/74/image_01217.jpg
# flowers/train/74/image_01261.jpg
# flowers/train/74/image_01282.jpg
# flowers/train/74/image_01170.jpg
# flowers/train/74/image_01212.jpg
# flowers/train/74/image_01273.jpg
# flowers/train/74/image_01194.jpg
# flowers/train/74/image_01232.jpg
# flowers/train/74/image_01255.jpg
# flowers/train/74/image_01313.jpg
# flowers/train/74/image_01179.jpg
# flowers/train/74/image_01214.jpg
# flowers/train/74/image_01283.jpg
# flowers/train/74/image_01259.jpg
# flowers/train/74/image_01203.jpg
# flowers/train/74/image_01303.jpg
# flowers/train/74/image_01287.jpg
# flowers/train/74/image_01156.jpg
# flowers/train/74/image_01242.jpg
# flowers/train/74/image_01272.jpg
# flowers/train/74/image_01299.jpg
# flowers/train/74/image_01168.jpg
# flowers/train/74/image_01211.jpg
# flowers/train/74/image_01297.jpg
# flowers/train/74/image_01286.jpg
# flowers/train/74/image_01278.jpg
# flowers/train/74/image_01223.jpg
# flowers/train/74/image_01292.jpg
# flowers/train/74/image_01215.jpg
# flowers/train/74/image_01205.jpg
# flowers/train/74/image_01239.jpg
# flowers/train/74/image_01267.jpg
# flowers/train/74/image_01182.jpg
# flowers/train/74/image_01144.jpg
# flowers/train/74/image_01164.jpg
# flowers/train/74/image_01309.jpg
# flowers/train/74/image_01291.jpg
# flowers/train/74/image_01270.jpg
# flowers/train/74/image_01145.jpg
# flowers/train/74/image_01208.jpg
# flowers/train/74/image_01199.jpg
# flowers/train/74/image_01206.jpg
# flowers/train/74/image_01236.jpg
# flowers/train/74/image_01195.jpg
# flowers/train/74/image_01245.jpg
# flowers/train/74/image_01210.jpg
# flowers/train/74/image_01207.jpg
# flowers/train/74/image_01277.jpg
# flowers/train/74/image_01295.jpg
# flowers/train/74/image_01274.jpg
# flowers/train/74/image_01159.jpg
# flowers/train/74/image_01224.jpg
# flowers/train/74/image_01300.jpg
# flowers/train/74/image_01143.jpg
# flowers/train/74/image_01230.jpg
# flowers/train/74/image_01201.jpg
# flowers/train/74/image_01306.jpg
# flowers/train/74/image_01184.jpg
# flowers/train/74/image_01290.jpg
# flowers/train/74/image_01197.jpg
# flowers/train/74/image_01171.jpg
# flowers/train/74/image_01216.jpg
# flowers/train/74/image_01193.jpg
# flowers/train/74/image_01250.jpg
# flowers/train/74/image_01225.jpg
# flowers/train/74/image_01147.jpg
# flowers/train/74/image_01228.jpg
# flowers/train/74/image_01226.jpg
# flowers/train/74/image_01187.jpg
# flowers/train/74/image_01188.jpg
# flowers/train/74/image_01285.jpg
# flowers/train/74/image_01219.jpg
# flowers/train/74/image_01298.jpg
# flowers/train/74/image_01233.jpg
# flowers/train/74/image_01162.jpg
# flowers/train/74/image_01253.jpg
# flowers/train/74/image_01154.jpg
# flowers/train/74/image_01240.jpg
# flowers/train/74/image_01234.jpg
# flowers/train/74/image_01163.jpg
# flowers/train/74/image_01281.jpg
# flowers/train/74/image_01174.jpg
# flowers/train/74/image_01268.jpg
# flowers/train/74/image_01263.jpg
# flowers/train/74/image_01153.jpg
# flowers/train/74/image_01181.jpg
# flowers/train/74/image_01196.jpg
# flowers/train/74/image_01180.jpg
# flowers/train/74/image_01280.jpg
# flowers/train/82/
# flowers/train/82/image_01627.jpg
# flowers/train/82/image_01632.jpg
# flowers/train/82/image_01655.jpg
# flowers/train/82/image_01688.jpg
# flowers/train/82/image_01644.jpg
# flowers/train/82/image_01612.jpg
# flowers/train/82/image_01600.jpg
# flowers/train/82/image_01692.jpg
# flowers/train/82/image_01584.jpg
# flowers/train/82/image_01646.jpg
# flowers/train/82/image_01631.jpg
# flowers/train/82/image_01626.jpg
# flowers/train/82/image_01674.jpg
# flowers/train/82/image_01619.jpg
# flowers/train/82/image_01663.jpg
# flowers/train/82/image_01605.jpg
# flowers/train/82/image_01607.jpg
# flowers/train/82/image_01657.jpg
# flowers/train/82/image_01622.jpg
# flowers/train/82/image_01638.jpg
# flowers/train/82/image_01676.jpg
# flowers/train/82/image_01606.jpg
# flowers/train/82/image_01591.jpg
# flowers/train/82/image_01636.jpg
# flowers/train/82/image_01608.jpg
# flowers/train/82/image_01593.jpg
# flowers/train/82/image_01628.jpg
# flowers/train/82/image_01678.jpg
# flowers/train/82/image_01635.jpg
# flowers/train/82/image_01642.jpg
# flowers/train/82/image_01652.jpg
# flowers/train/82/image_01668.jpg
# flowers/train/82/image_01633.jpg
# flowers/train/82/image_01660.jpg
# flowers/train/82/image_01624.jpg
# flowers/train/82/image_01695.jpg
# flowers/train/82/image_01634.jpg
# flowers/train/82/image_01637.jpg
# flowers/train/82/image_01667.jpg
# flowers/train/82/image_01670.jpg
# flowers/train/82/image_01585.jpg
# flowers/train/82/image_01656.jpg
# flowers/train/82/image_01687.jpg
# flowers/train/82/image_01616.jpg
# flowers/train/82/image_01645.jpg
# flowers/train/82/image_01623.jpg
# flowers/train/82/image_01675.jpg
# flowers/train/82/image_01639.jpg
# flowers/train/82/image_01669.jpg
# flowers/train/82/image_01613.jpg
# flowers/train/82/image_01611.jpg
# flowers/train/82/image_01602.jpg
# flowers/train/82/image_01654.jpg
# flowers/train/82/image_01588.jpg
# flowers/train/82/image_01597.jpg
# flowers/train/82/image_01681.jpg
# flowers/train/82/image_01665.jpg
# flowers/train/82/image_01682.jpg
# flowers/train/82/image_01651.jpg
# flowers/train/82/image_01677.jpg
# flowers/train/82/image_01615.jpg
# flowers/train/82/image_01601.jpg
# flowers/train/82/image_01647.jpg
# flowers/train/82/image_01694.jpg
# flowers/train/82/image_01586.jpg
# flowers/train/82/image_01595.jpg
# flowers/train/82/image_01629.jpg
# flowers/train/82/image_01689.jpg
# flowers/train/82/image_01589.jpg
# flowers/train/82/image_01621.jpg
# flowers/train/82/image_01664.jpg
# flowers/train/82/image_01648.jpg
# flowers/train/82/image_01684.jpg
# flowers/train/82/image_01641.jpg
# flowers/train/82/image_01630.jpg
# flowers/train/82/image_01587.jpg
# flowers/train/82/image_01590.jpg
# flowers/train/82/image_01680.jpg
# flowers/train/82/image_01617.jpg
# flowers/train/82/image_01620.jpg
# flowers/train/82/image_01604.jpg
# flowers/train/82/image_01673.jpg
# flowers/train/58/
# flowers/train/58/image_02720.jpg
# flowers/train/58/image_02697.jpg
# flowers/train/58/image_02692.jpg
# flowers/train/58/image_02706.jpg
# flowers/train/58/image_02640.jpg
# flowers/train/58/image_02680.jpg
# flowers/train/58/image_02730.jpg
# flowers/train/58/image_02747.jpg
# flowers/train/58/image_02671.jpg
# flowers/train/58/image_02661.jpg
# flowers/train/58/image_02751.jpg
# flowers/train/58/image_02667.jpg
# flowers/train/58/image_02699.jpg
# flowers/train/58/image_02724.jpg
# flowers/train/58/image_02688.jpg
# flowers/train/58/image_02729.jpg
# flowers/train/58/image_02715.jpg
# flowers/train/58/image_02652.jpg
# flowers/train/58/image_02685.jpg
# flowers/train/58/image_02668.jpg
# flowers/train/58/image_02646.jpg
# flowers/train/58/image_02712.jpg
# flowers/train/58/image_02718.jpg
# flowers/train/58/image_02746.jpg
# flowers/train/58/image_02670.jpg
# flowers/train/58/image_02714.jpg
# flowers/train/58/image_02659.jpg
# flowers/train/58/image_02673.jpg
# flowers/train/58/image_02657.jpg
# flowers/train/58/image_02645.jpg
# flowers/train/58/image_02683.jpg
# flowers/train/58/image_02698.jpg
# flowers/train/58/image_02717.jpg
# flowers/train/58/image_02641.jpg
# flowers/train/58/image_02749.jpg
# flowers/train/58/image_02750.jpg
# flowers/train/58/image_02711.jpg
# flowers/train/58/image_02727.jpg
# flowers/train/58/image_02707.jpg
# flowers/train/58/image_02684.jpg
# flowers/train/58/image_02745.jpg
# flowers/train/58/image_02648.jpg
# flowers/train/58/image_02739.jpg
# flowers/train/58/image_02660.jpg
# flowers/train/58/image_02703.jpg
# flowers/train/58/image_02740.jpg
# flowers/train/58/image_02643.jpg
# flowers/train/58/image_02682.jpg
# flowers/train/58/image_02655.jpg
# flowers/train/58/image_02744.jpg
# flowers/train/58/image_02713.jpg
# flowers/train/58/image_02732.jpg
# flowers/train/58/image_02696.jpg
# flowers/train/58/image_02693.jpg
# flowers/train/58/image_02674.jpg
# flowers/train/58/image_02736.jpg
# flowers/train/58/image_02689.jpg
# flowers/train/58/image_02654.jpg
# flowers/train/58/image_02662.jpg
# flowers/train/58/image_02701.jpg
# flowers/train/58/image_02651.jpg
# flowers/train/58/image_02666.jpg
# flowers/train/58/image_02710.jpg
# flowers/train/58/image_02716.jpg
# flowers/train/58/image_02748.jpg
# flowers/train/58/image_02731.jpg
# flowers/train/58/image_02735.jpg
# flowers/train/58/image_02733.jpg
# flowers/train/58/image_02647.jpg
# flowers/train/58/image_02658.jpg
# flowers/train/58/image_02728.jpg
# flowers/train/58/image_02723.jpg
# flowers/train/58/image_02679.jpg
# flowers/train/58/image_02639.jpg
# flowers/train/58/image_02644.jpg
# flowers/train/58/image_02669.jpg
# flowers/train/58/image_02708.jpg
# flowers/train/58/image_02664.jpg
# flowers/train/58/image_02686.jpg
# flowers/train/58/image_02725.jpg
# flowers/train/58/image_02709.jpg
# flowers/train/58/image_02665.jpg
# flowers/train/58/image_02650.jpg
# flowers/train/58/image_02678.jpg
# flowers/train/58/image_02704.jpg
# flowers/train/58/image_02702.jpg
# flowers/train/41/
# flowers/train/41/image_02211.jpg
# flowers/train/41/image_02229.jpg
# flowers/train/41/image_02194.jpg
# flowers/train/41/image_02221.jpg
# flowers/train/41/image_02212.jpg
# flowers/train/41/image_02271.jpg
# flowers/train/41/image_02294.jpg
# flowers/train/41/image_02203.jpg
# flowers/train/41/image_02192.jpg
# flowers/train/41/image_02298.jpg
# flowers/train/41/image_02312.jpg
# flowers/train/41/image_02267.jpg
# flowers/train/41/image_02197.jpg
# flowers/train/41/image_02303.jpg
# flowers/train/41/image_02252.jpg
# flowers/train/41/image_02243.jpg
# flowers/train/41/image_02255.jpg
# flowers/train/41/image_02228.jpg
# flowers/train/41/image_02279.jpg
# flowers/train/41/image_02311.jpg
# flowers/train/41/image_02274.jpg
# flowers/train/41/image_02286.jpg
# flowers/train/41/image_02299.jpg
# flowers/train/41/image_02288.jpg
# flowers/train/41/image_02241.jpg
# flowers/train/41/image_02238.jpg
# flowers/train/41/image_02189.jpg
# flowers/train/41/image_02214.jpg
# flowers/train/41/image_02213.jpg
# flowers/train/41/image_02253.jpg
# flowers/train/41/image_02309.jpg
# flowers/train/41/image_02208.jpg
# flowers/train/41/image_02296.jpg
# flowers/train/41/image_02314.jpg
# flowers/train/41/image_02275.jpg
# flowers/train/41/image_02191.jpg
# flowers/train/41/image_02215.jpg
# flowers/train/41/image_02249.jpg
# flowers/train/41/image_02284.jpg
# flowers/train/41/image_02246.jpg
# flowers/train/41/image_02216.jpg
# flowers/train/41/image_02292.jpg
# flowers/train/41/image_02190.jpg
# flowers/train/41/image_02307.jpg
# flowers/train/41/image_02265.jpg
# flowers/train/41/image_02233.jpg
# flowers/train/41/image_02254.jpg
# flowers/train/41/image_02236.jpg
# flowers/train/41/image_02242.jpg
# flowers/train/41/image_02280.jpg
# flowers/train/41/image_02244.jpg
# flowers/train/41/image_02287.jpg
# flowers/train/41/image_02282.jpg
# flowers/train/41/image_02281.jpg
# flowers/train/41/image_02277.jpg
# flowers/train/41/image_02250.jpg
# flowers/train/41/image_02269.jpg
# flowers/train/41/image_02223.jpg
# flowers/train/41/image_02300.jpg
# flowers/train/41/image_02227.jpg
# flowers/train/41/image_02313.jpg
# flowers/train/41/image_02218.jpg
# flowers/train/41/image_02234.jpg
# flowers/train/41/image_02195.jpg
# flowers/train/41/image_02239.jpg
# flowers/train/41/image_02202.jpg
# flowers/train/41/image_02289.jpg
# flowers/train/41/image_02304.jpg
# flowers/train/41/image_02209.jpg
# flowers/train/41/image_02256.jpg
# flowers/train/41/image_02273.jpg
# flowers/train/41/image_02272.jpg
# flowers/train/41/image_02308.jpg
# flowers/train/41/image_02295.jpg
# flowers/train/41/image_02235.jpg
# flowers/train/41/image_02224.jpg
# flowers/train/41/image_02285.jpg
# flowers/train/41/image_02290.jpg
# flowers/train/41/image_02217.jpg
# flowers/train/41/image_02310.jpg
# flowers/train/41/image_02264.jpg
# flowers/train/41/image_02293.jpg
# flowers/train/41/image_02315.jpg
# flowers/train/41/image_02225.jpg
# flowers/train/41/image_02207.jpg
# flowers/train/41/image_02226.jpg
# flowers/train/41/image_02196.jpg
# flowers/train/41/image_02262.jpg
# flowers/train/41/image_02301.jpg
# flowers/train/41/image_02206.jpg
# flowers/train/41/image_02230.jpg
# flowers/train/41/image_02220.jpg
# flowers/train/41/image_02291.jpg
# flowers/train/41/image_02204.jpg
# flowers/train/41/image_02240.jpg
# flowers/train/41/image_02283.jpg
# flowers/train/41/image_02210.jpg
# flowers/train/51/
# flowers/train/51/image_01323.jpg
# flowers/train/51/image_01321.jpg
# flowers/train/51/image_01356.jpg
# flowers/train/51/image_01440.jpg
# flowers/train/51/image_03977.jpg
# flowers/train/51/image_01319.jpg
# flowers/train/51/image_01486.jpg
# flowers/train/51/image_03988.jpg
# flowers/train/51/image_01333.jpg
# flowers/train/51/image_01478.jpg
# flowers/train/51/image_03966.jpg
# flowers/train/51/image_01351.jpg
# flowers/train/51/image_01320.jpg
# flowers/train/51/image_03993.jpg
# flowers/train/51/image_01334.jpg
# flowers/train/51/image_01490.jpg
# flowers/train/51/image_01466.jpg
# flowers/train/51/image_01327.jpg
# flowers/train/51/image_01488.jpg
# flowers/train/51/image_01460.jpg
# flowers/train/51/image_01377.jpg
# flowers/train/51/image_03949.jpg
# flowers/train/51/image_01451.jpg
# flowers/train/51/image_01360.jpg
# flowers/train/51/image_01434.jpg
# flowers/train/51/image_01461.jpg
# flowers/train/51/image_03930.jpg
# flowers/train/51/image_03923.jpg
# flowers/train/51/image_01427.jpg
# flowers/train/51/image_01384.jpg
# flowers/train/51/image_01355.jpg
# flowers/train/51/image_01430.jpg
# flowers/train/51/image_03941.jpg
# flowers/train/51/image_01344.jpg
# flowers/train/51/image_01428.jpg
# flowers/train/51/image_01467.jpg
# flowers/train/51/image_03928.jpg
# flowers/train/51/image_01393.jpg
# flowers/train/51/image_03992.jpg
# flowers/train/51/image_01455.jpg
# flowers/train/51/image_01345.jpg
# flowers/train/51/image_03979.jpg
# flowers/train/51/image_01324.jpg
# flowers/train/51/image_01364.jpg
# flowers/train/51/image_01387.jpg
# flowers/train/51/image_01450.jpg
# flowers/train/51/image_03972.jpg
# flowers/train/51/image_01416.jpg
# flowers/train/51/image_03932.jpg
# flowers/train/51/image_01424.jpg
# flowers/train/51/image_01368.jpg
# flowers/train/51/image_01371.jpg
# flowers/train/51/image_01358.jpg
# flowers/train/51/image_01374.jpg
# flowers/train/51/image_01375.jpg
# flowers/train/51/image_03970.jpg
# flowers/train/51/image_01489.jpg
# flowers/train/51/image_01337.jpg
# flowers/train/51/image_01456.jpg
# flowers/train/51/image_01472.jpg
# flowers/train/51/image_01341.jpg
# flowers/train/51/image_01458.jpg
# flowers/train/51/image_01317.jpg
# flowers/train/51/image_03919.jpg
# flowers/train/51/image_01464.jpg
# flowers/train/51/image_01433.jpg
# flowers/train/51/image_03950.jpg
# flowers/train/51/image_01444.jpg
# flowers/train/51/image_01431.jpg
# flowers/train/51/image_01470.jpg
# flowers/train/51/image_01438.jpg
# flowers/train/51/image_01408.jpg
# flowers/train/51/image_01436.jpg
# flowers/train/51/image_01366.jpg
# flowers/train/51/image_03922.jpg
# flowers/train/51/image_01420.jpg
# flowers/train/51/image_01463.jpg
# flowers/train/51/image_01367.jpg
# flowers/train/51/image_01447.jpg
# flowers/train/51/image_01487.jpg
# flowers/train/51/image_01477.jpg
# flowers/train/51/image_03962.jpg
# flowers/train/51/image_01432.jpg
# flowers/train/51/image_01403.jpg
# flowers/train/51/image_01437.jpg
# flowers/train/51/image_03925.jpg
# flowers/train/51/image_03983.jpg
# flowers/train/51/image_01342.jpg
# flowers/train/51/image_01373.jpg
# flowers/train/51/image_03963.jpg
# flowers/train/51/image_01445.jpg
# flowers/train/51/image_03914.jpg
# flowers/train/51/image_01325.jpg
# flowers/train/51/image_01378.jpg
# flowers/train/51/image_03990.jpg
# flowers/train/51/image_01365.jpg
# flowers/train/51/image_01343.jpg
# flowers/train/51/image_03947.jpg
# flowers/train/51/image_03955.jpg
# flowers/train/51/image_01379.jpg
# flowers/train/51/image_01390.jpg
# flowers/train/51/image_03958.jpg
# flowers/train/51/image_01471.jpg
# flowers/train/51/image_01409.jpg
# flowers/train/51/image_03913.jpg
# flowers/train/51/image_01485.jpg
# flowers/train/51/image_01353.jpg
# flowers/train/51/image_01405.jpg
# flowers/train/51/image_03936.jpg
# flowers/train/51/image_03971.jpg
# flowers/train/51/image_03924.jpg
# flowers/train/51/image_01411.jpg
# flowers/train/51/image_01369.jpg
# flowers/train/51/image_01426.jpg
# flowers/train/51/image_01383.jpg
# flowers/train/51/image_01357.jpg
# flowers/train/51/image_01402.jpg
# flowers/train/51/image_03969.jpg
# flowers/train/51/image_03987.jpg
# flowers/train/51/image_03956.jpg
# flowers/train/51/image_01417.jpg
# flowers/train/51/image_03945.jpg
# flowers/train/51/image_01376.jpg
# flowers/train/51/image_03953.jpg
# flowers/train/51/image_03982.jpg
# flowers/train/51/image_01415.jpg
# flowers/train/51/image_03952.jpg
# flowers/train/51/image_01422.jpg
# flowers/train/51/image_01381.jpg
# flowers/train/51/image_01380.jpg
# flowers/train/51/image_03948.jpg
# flowers/train/51/image_01483.jpg
# flowers/train/51/image_01481.jpg
# flowers/train/51/image_03967.jpg
# flowers/train/51/image_01339.jpg
# flowers/train/51/image_03918.jpg
# flowers/train/51/image_01482.jpg
# flowers/train/51/image_01452.jpg
# flowers/train/51/image_01338.jpg
# flowers/train/51/image_03976.jpg
# flowers/train/51/image_03942.jpg
# flowers/train/51/image_01441.jpg
# flowers/train/51/image_03915.jpg
# flowers/train/51/image_03964.jpg
# flowers/train/51/image_01372.jpg
# flowers/train/51/image_01484.jpg
# flowers/train/51/image_01336.jpg
# flowers/train/51/image_03940.jpg
# flowers/train/51/image_01465.jpg
# flowers/train/51/image_01453.jpg
# flowers/train/51/image_01400.jpg
# flowers/train/51/image_01399.jpg
# flowers/train/51/image_01479.jpg
# flowers/train/51/image_01394.jpg
# flowers/train/51/image_01429.jpg
# flowers/train/51/image_03965.jpg
# flowers/train/51/image_01421.jpg
# flowers/train/51/image_03991.jpg
# flowers/train/51/image_01443.jpg
# flowers/train/51/image_01347.jpg
# flowers/train/51/image_01401.jpg
# flowers/train/51/image_01392.jpg
# flowers/train/51/image_01448.jpg
# flowers/train/51/image_03944.jpg
# flowers/train/51/image_01349.jpg
# flowers/train/51/image_01397.jpg
# flowers/train/51/image_01386.jpg
# flowers/train/51/image_01395.jpg
# flowers/train/51/image_01361.jpg
# flowers/train/51/image_01348.jpg
# flowers/train/51/image_01331.jpg
# flowers/train/51/image_01442.jpg
# flowers/train/51/image_01385.jpg
# flowers/train/51/image_03959.jpg
# flowers/train/51/image_01332.jpg
# flowers/train/51/image_01350.jpg
# flowers/train/51/image_03957.jpg
# flowers/train/51/image_01454.jpg
# flowers/train/51/image_01318.jpg
# flowers/train/51/image_01413.jpg
# flowers/train/51/image_03935.jpg
# flowers/train/51/image_01412.jpg
# flowers/train/51/image_01449.jpg
# flowers/train/51/image_03981.jpg
# flowers/train/51/image_01382.jpg
# flowers/train/51/image_01435.jpg
# flowers/train/51/image_03929.jpg
# flowers/train/51/image_03921.jpg
# flowers/train/51/image_01410.jpg
# flowers/train/51/image_01396.jpg
# flowers/train/51/image_01404.jpg
# flowers/train/51/image_01330.jpg
# flowers/train/51/image_01446.jpg
# flowers/train/51/image_01398.jpg
# flowers/train/51/image_01476.jpg
# flowers/train/51/image_01423.jpg
# flowers/train/51/image_01418.jpg
# flowers/train/51/image_03931.jpg
# flowers/train/51/image_01462.jpg
# flowers/train/51/image_01359.jpg
# flowers/train/51/image_01329.jpg
# flowers/train/51/image_01480.jpg
# flowers/train/51/image_03920.jpg
# flowers/train/51/image_01475.jpg
# flowers/train/51/image_03978.jpg
# flowers/train/51/image_03934.jpg
# flowers/train/93/
# flowers/train/93/image_08116.jpg
# flowers/train/93/image_08115.jpg
# flowers/train/93/image_06015.jpg
# flowers/train/93/image_06036.jpg
# flowers/train/93/image_06045.jpg
# flowers/train/93/image_06025.jpg
# flowers/train/93/image_06018.jpg
# flowers/train/93/image_06032.jpg
# flowers/train/93/image_06020.jpg
# flowers/train/93/image_06046.jpg
# flowers/train/93/image_06026.jpg
# flowers/train/93/image_06030.jpg
# flowers/train/93/image_06039.jpg
# flowers/train/93/image_06022.jpg
# flowers/train/93/image_06023.jpg
# flowers/train/93/image_06029.jpg
# flowers/train/93/image_06012.jpg
# flowers/train/93/image_06011.jpg
# flowers/train/93/image_06047.jpg
# flowers/train/93/image_06043.jpg
# flowers/train/93/image_06034.jpg
# flowers/train/93/image_06016.jpg
# flowers/train/93/image_06013.jpg
# flowers/train/93/image_06019.jpg
# flowers/train/93/image_06042.jpg
# flowers/train/93/image_06040.jpg
# flowers/train/93/image_08117.jpg
# flowers/train/93/image_08112.jpg
# flowers/train/93/image_06028.jpg
# flowers/train/93/image_06027.jpg
# flowers/train/93/image_08114.jpg
# flowers/train/93/image_06038.jpg
# flowers/train/93/image_06041.jpg
# flowers/train/93/image_06035.jpg
# flowers/train/53/
# flowers/train/53/image_03713.jpg
# flowers/train/53/image_03728.jpg
# flowers/train/53/image_03692.jpg
# flowers/train/53/image_03722.jpg
# flowers/train/53/image_03681.jpg
# flowers/train/53/image_03644.jpg
# flowers/train/53/image_03678.jpg
# flowers/train/53/image_03651.jpg
# flowers/train/53/image_03685.jpg
# flowers/train/53/image_03706.jpg
# flowers/train/53/image_03709.jpg
# flowers/train/53/image_03663.jpg
# flowers/train/53/image_03716.jpg
# flowers/train/53/image_03682.jpg
# flowers/train/53/image_03721.jpg
# flowers/train/53/image_03725.jpg
# flowers/train/53/image_03707.jpg
# flowers/train/53/image_03688.jpg
# flowers/train/53/image_03731.jpg
# flowers/train/53/image_03647.jpg
# flowers/train/53/image_03711.jpg
# flowers/train/53/image_03704.jpg
# flowers/train/53/image_03671.jpg
# flowers/train/53/image_03664.jpg
# flowers/train/53/image_03673.jpg
# flowers/train/53/image_03684.jpg
# flowers/train/53/image_03658.jpg
# flowers/train/53/image_03657.jpg
# flowers/train/53/image_03697.jpg
# flowers/train/53/image_03686.jpg
# flowers/train/53/image_03683.jpg
# flowers/train/53/image_03710.jpg
# flowers/train/53/image_03679.jpg
# flowers/train/53/image_03642.jpg
# flowers/train/53/image_03701.jpg
# flowers/train/53/image_03698.jpg
# flowers/train/53/image_03726.jpg
# flowers/train/53/image_03641.jpg
# flowers/train/53/image_03666.jpg
# flowers/train/53/image_03699.jpg
# flowers/train/53/image_03646.jpg
# flowers/train/53/image_03643.jpg
# flowers/train/53/image_03659.jpg
# flowers/train/53/image_03705.jpg
# flowers/train/53/image_03675.jpg
# flowers/train/53/image_03665.jpg
# flowers/train/53/image_03661.jpg
# flowers/train/53/image_03708.jpg
# flowers/train/53/image_03730.jpg
# flowers/train/53/image_03680.jpg
# flowers/train/53/image_03696.jpg
# flowers/train/53/image_03732.jpg
# flowers/train/53/image_03674.jpg
# flowers/train/53/image_03676.jpg
# flowers/train/53/image_03719.jpg
# flowers/train/53/image_03703.jpg
# flowers/train/53/image_03690.jpg
# flowers/train/53/image_03700.jpg
# flowers/train/53/image_03695.jpg
# flowers/train/53/image_03723.jpg
# flowers/train/53/image_03650.jpg
# flowers/train/53/image_03727.jpg
# flowers/train/53/image_03715.jpg
# flowers/train/53/image_03720.jpg
# flowers/train/53/image_03729.jpg
# flowers/train/53/image_03687.jpg
# flowers/train/53/image_03660.jpg
# flowers/train/53/image_03691.jpg
# flowers/train/53/image_03694.jpg
# flowers/train/53/image_03648.jpg
# flowers/train/14/
# flowers/train/14/image_06069.jpg
# flowers/train/14/image_06077.jpg
# flowers/train/14/image_06066.jpg
# flowers/train/14/image_06078.jpg
# flowers/train/14/image_06056.jpg
# flowers/train/14/image_06081.jpg
# flowers/train/14/image_06080.jpg
# flowers/train/14/image_06076.jpg
# flowers/train/14/image_06089.jpg
# flowers/train/14/image_06065.jpg
# flowers/train/14/image_06093.jpg
# flowers/train/14/image_06054.jpg
# flowers/train/14/image_06067.jpg
# flowers/train/14/image_06068.jpg
# flowers/train/14/image_06063.jpg
# flowers/train/14/image_06059.jpg
# flowers/train/14/image_06092.jpg
# flowers/train/14/image_06072.jpg
# flowers/train/14/image_06095.jpg
# flowers/train/14/image_06087.jpg
# flowers/train/14/image_06096.jpg
# flowers/train/14/image_06088.jpg
# flowers/train/14/image_06086.jpg
# flowers/train/14/image_06064.jpg
# flowers/train/14/image_06050.jpg
# flowers/train/14/image_06057.jpg
# flowers/train/14/image_06053.jpg
# flowers/train/14/image_06073.jpg
# flowers/train/14/image_06075.jpg
# flowers/train/14/image_06071.jpg
# flowers/train/14/image_06060.jpg
# flowers/train/14/image_06049.jpg
# flowers/train/14/image_06084.jpg
# flowers/train/14/image_06074.jpg
# flowers/train/14/image_06070.jpg
# flowers/train/14/image_06061.jpg
# flowers/train/14/image_06090.jpg
# flowers/train/14/image_06094.jpg
# flowers/train/14/image_06085.jpg
# flowers/train/14/image_06079.jpg
# flowers/train/14/image_06058.jpg
# flowers/train/14/image_06062.jpg
# flowers/train/14/image_06051.jpg
# flowers/train/14/image_06055.jpg
# flowers/train/87/
# flowers/train/87/image_05463.jpg
# flowers/train/87/image_05491.jpg
# flowers/train/87/image_05486.jpg
# flowers/train/87/image_05503.jpg
# flowers/train/87/image_05504.jpg
# flowers/train/87/image_05496.jpg
# flowers/train/87/image_05494.jpg
# flowers/train/87/image_05501.jpg
# flowers/train/87/image_05513.jpg
# flowers/train/87/image_05465.jpg
# flowers/train/87/image_05515.jpg
# flowers/train/87/image_05521.jpg
# flowers/train/87/image_05471.jpg
# flowers/train/87/image_05477.jpg
# flowers/train/87/image_05470.jpg
# flowers/train/87/image_05460.jpg
# flowers/train/87/image_05478.jpg
# flowers/train/87/image_05475.jpg
# flowers/train/87/image_05517.jpg
# flowers/train/87/image_05476.jpg
# flowers/train/87/image_05512.jpg
# flowers/train/87/image_05490.jpg
# flowers/train/87/image_05514.jpg
# flowers/train/87/image_05468.jpg
# flowers/train/87/image_05516.jpg
# flowers/train/87/image_05492.jpg
# flowers/train/87/image_05489.jpg
# flowers/train/87/image_05480.jpg
# flowers/train/87/image_05505.jpg
# flowers/train/87/image_05511.jpg
# flowers/train/87/image_05498.jpg
# flowers/train/87/image_05497.jpg
# flowers/train/87/image_05464.jpg
# flowers/train/87/image_05506.jpg
# flowers/train/87/image_05510.jpg
# flowers/train/87/image_05473.jpg
# flowers/train/87/image_05482.jpg
# flowers/train/87/image_05479.jpg
# flowers/train/87/image_05461.jpg
# flowers/train/87/image_05481.jpg
# flowers/train/87/image_05467.jpg
# flowers/train/87/image_05519.jpg
# flowers/train/87/image_05518.jpg
# flowers/train/87/image_05500.jpg
# flowers/train/87/image_05474.jpg
# flowers/train/87/image_05509.jpg
# flowers/train/87/image_05495.jpg
# flowers/train/87/image_05472.jpg
# flowers/train/87/image_05499.jpg
# flowers/train/87/image_05522.jpg
# flowers/train/87/image_05483.jpg
# flowers/train/5/
# flowers/train/5/image_05195.jpg
# flowers/train/5/image_05175.jpg
# flowers/train/5/image_05185.jpg
# flowers/train/5/image_05203.jpg
# flowers/train/5/image_05151.jpg
# flowers/train/5/image_05205.jpg
# flowers/train/5/image_05153.jpg
# flowers/train/5/image_05200.jpg
# flowers/train/5/image_05183.jpg
# ...
# flowers/valid/63/image_05898.jpg
# flowers/valid/63/image_05857.jpg
# flowers/valid/63/image_05876.jpg
# flowers/valid/63/image_05867.jpg
# flowers/valid/63/image_05853.jpg
# flowers/valid/63/image_05861.jpg
# flowers/valid/22/
# flowers/valid/22/image_05364.jpg
# flowers/valid/22/image_05361.jpg
# flowers/valid/22/image_05381.jpg
# flowers/valid/22/image_05388.jpg
# flowers/valid/22/image_05368.jpg
# flowers/valid/22/image_05376.jpg
# flowers/valid/22/image_05352.jpg
# flowers/valid/22/image_05398.jpg
# flowers/valid/80/
# flowers/valid/80/image_02011.jpg
# flowers/valid/80/image_02021.jpg
# flowers/valid/80/image_02050.jpg
# flowers/valid/80/image_01989.jpg
# flowers/valid/80/image_01992.jpg
# flowers/valid/80/image_01975.jpg
# flowers/valid/80/image_02017.jpg
# flowers/valid/80/image_01972.jpg
# flowers/valid/80/image_01991.jpg
# flowers/valid/80/image_02042.jpg
# flowers/valid/80/image_02005.jpg
# flowers/valid/80/image_01979.jpg
# flowers/valid/47/
# flowers/valid/47/image_05007.jpg
# flowers/valid/47/image_04989.jpg
# flowers/valid/47/image_04957.jpg
# flowers/valid/40/
# flowers/valid/40/image_04584.jpg
# flowers/valid/40/image_04608.jpg
# flowers/valid/40/image_04579.jpg
# flowers/valid/40/image_04578.jpg
# flowers/valid/40/image_04596.jpg
# flowers/valid/11/
# flowers/valid/11/image_03157.jpg
# flowers/valid/11/image_03173.jpg
# flowers/valid/11/image_03108.jpg
# flowers/valid/11/image_03125.jpg
# flowers/valid/11/image_03116.jpg
# flowers/valid/11/image_03128.jpg
# flowers/valid/11/image_03111.jpg
# flowers/valid/11/image_03139.jpg
# flowers/valid/11/image_03145.jpg
# flowers/valid/11/image_03100.jpg
# flowers/valid/64/
# flowers/valid/64/image_06098.jpg
# flowers/valid/64/image_06141.jpg
# flowers/valid/64/image_06123.jpg
# flowers/valid/64/image_06129.jpg
# flowers/valid/64/image_06126.jpg
# flowers/valid/37/
# flowers/valid/37/image_03768.jpg
# flowers/valid/37/image_03765.jpg
# flowers/valid/37/image_03822.jpg
# flowers/valid/37/image_03785.jpg
# flowers/valid/37/image_03820.jpg
# flowers/valid/37/image_03813.jpg
# flowers/valid/37/image_03756.jpg
# flowers/valid/37/image_03810.jpg
# flowers/valid/36/
# flowers/valid/36/image_04351.jpg
# flowers/valid/36/image_04350.jpg
# flowers/valid/36/image_04352.jpg
# flowers/valid/36/image_04333.jpg
# flowers/valid/36/image_04354.jpg
# flowers/valid/36/image_04393.jpg
# flowers/valid/86/
# flowers/valid/86/image_02906.jpg
# flowers/valid/86/image_02891.jpg
# flowers/valid/86/image_02887.jpg
# flowers/valid/86/image_02909.jpg
# flowers/valid/86/image_02901.jpg
# flowers/valid/17/
# flowers/valid/17/image_03842.jpg
# flowers/valid/17/image_03854.jpg
# flowers/valid/17/image_03851.jpg
# flowers/valid/17/image_03876.jpg
# flowers/valid/17/image_03829.jpg
# flowers/valid/17/image_03883.jpg
# flowers/valid/17/image_03831.jpg
# flowers/valid/17/image_03868.jpg
# flowers/valid/17/image_03890.jpg
# flowers/valid/17/image_03839.jpg
# flowers/valid/17/image_03908.jpg
# flowers/valid/17/image_03856.jpg
# flowers/valid/17/image_03834.jpg
# flowers/valid/17/image_03837.jpg
# flowers/valid/17/image_03843.jpg
# flowers/valid/17/image_03907.jpg
# flowers/valid/66/
# flowers/valid/66/image_05577.jpg
# flowers/valid/66/image_05565.jpg
# flowers/valid/66/image_05579.jpg
# flowers/valid/66/image_05563.jpg
# flowers/valid/66/image_05560.jpg
# flowers/valid/66/image_05559.jpg
# flowers/valid/65/
# flowers/valid/65/image_03222.jpg
# flowers/valid/65/image_03193.jpg
# flowers/valid/65/image_03241.jpg
# flowers/valid/65/image_03276.jpg
# flowers/valid/65/image_03250.jpg
# flowers/valid/65/image_03224.jpg
# flowers/valid/65/image_03279.jpg
# flowers/valid/59/
# flowers/valid/59/image_05077.jpg
# flowers/valid/59/image_05056.jpg
# flowers/valid/59/image_05086.jpg
# flowers/valid/59/image_05034.jpg
# flowers/valid/45/
# flowers/valid/45/image_07127.jpg
# flowers/valid/45/image_07160.jpg
# flowers/valid/45/image_07137.jpg
# flowers/valid/45/image_07155.jpg
# flowers/valid/10/
# flowers/valid/10/image_07102.jpg
# flowers/valid/10/image_07107.jpg
# flowers/valid/10/image_07101.jpg
# flowers/valid/10/image_07094.jpg
# flowers/valid/78/
# flowers/valid/78/image_01937.jpg
# flowers/valid/78/image_01944.jpg
# flowers/valid/78/image_01929.jpg
# flowers/valid/78/image_01910.jpg
# flowers/valid/78/image_01862.jpg
# flowers/valid/78/image_01938.jpg
# flowers/valid/78/image_01962.jpg
# flowers/valid/78/image_01914.jpg
# flowers/valid/78/image_01922.jpg
# flowers/valid/78/image_01844.jpg
# flowers/valid/78/image_01894.jpg
# flowers/valid/94/
# flowers/valid/94/image_07317.jpg
# flowers/valid/94/image_07408.jpg
# flowers/valid/94/image_07325.jpg
# flowers/valid/94/image_07428.jpg
# flowers/valid/94/image_07381.jpg
# flowers/valid/94/image_07449.jpg
# flowers/valid/94/image_07385.jpg
# flowers/valid/94/image_07372.jpg
# flowers/valid/94/image_07382.jpg
# flowers/valid/94/image_07360.jpg
# flowers/valid/94/image_07435.jpg
# flowers/valid/94/image_07393.jpg
# flowers/valid/94/image_07418.jpg
# flowers/valid/94/image_07392.jpg
# flowers/valid/31/
# flowers/valid/31/image_06905.jpg
# flowers/valid/31/image_08067.jpg
# flowers/valid/77/
# flowers/valid/77/image_00137.jpg
# flowers/valid/77/image_00178.jpg
# flowers/valid/77/image_00063.jpg
# flowers/valid/77/image_00081.jpg
# flowers/valid/77/image_00112.jpg
# flowers/valid/77/image_00078.jpg
# flowers/valid/77/image_00245.jpg
# flowers/valid/77/image_00160.jpg
# flowers/valid/77/image_00072.jpg
# flowers/valid/77/image_00071.jpg
# flowers/valid/77/image_00028.jpg
# flowers/valid/77/image_00188.jpg
# flowers/valid/77/image_00061.jpg
# flowers/valid/77/image_00104.jpg
# flowers/valid/77/image_00218.jpg
# flowers/valid/77/image_00174.jpg
# flowers/valid/77/image_00200.jpg
# flowers/valid/77/image_00059.jpg
# flowers/valid/77/image_00231.jpg
# flowers/valid/77/image_00143.jpg
# flowers/valid/77/image_00246.jpg
# flowers/valid/7/
# flowers/valid/7/image_07216.jpg
# flowers/valid/2/
# flowers/valid/2/image_05142.jpg
# flowers/valid/2/image_05124.jpg
# flowers/valid/2/image_05101.jpg
# flowers/valid/2/image_05136.jpg
# flowers/valid/2/image_05137.jpg
# flowers/valid/2/image_05094.jpg
# flowers/valid/56/
# flowers/valid/56/image_02858.jpg
# flowers/valid/56/image_02857.jpg
# flowers/valid/56/image_02769.jpg
# flowers/valid/56/image_02788.jpg
# flowers/valid/56/image_02771.jpg
# flowers/valid/56/image_02805.jpg
# flowers/valid/56/image_02773.jpg
# flowers/valid/56/image_02792.jpg
# flowers/valid/56/image_02849.jpg
# flowers/valid/3/
# flowers/valid/3/image_06631.jpg
# flowers/valid/3/image_06621.jpg
# flowers/valid/72/
# flowers/valid/72/image_03559.jpg
# flowers/valid/72/image_03565.jpg
# flowers/valid/72/image_03587.jpg
# flowers/valid/72/image_03584.jpg
# flowers/valid/72/image_03561.jpg
# flowers/valid/72/image_03568.jpg
# flowers/valid/72/image_03576.jpg
# flowers/valid/72/image_03632.jpg
# flowers/valid/21/
# flowers/valid/21/image_06784.jpg
# flowers/valid/21/image_06804.jpg
# flowers/valid/21/image_06778.jpg
# flowers/valid/21/image_06788.jpg
# flowers/valid/35/
# flowers/valid/35/image_06977.jpg
# flowers/valid/35/image_07004.jpg
# flowers/valid/35/image_06978.jpg
# flowers/valid/35/image_07005.jpg
# flowers/valid/26/
# flowers/valid/26/image_06506.jpg
# flowers/valid/26/image_06501.jpg
# flowers/valid/26/image_06516.jpg
# flowers/valid/100/
# flowers/valid/100/image_07931.jpg
# flowers/valid/100/image_07904.jpg
# flowers/valid/100/image_07929.jpg
# flowers/valid/100/image_07895.jpg
# flowers/valid/100/image_07917.jpg
# flowers/valid/100/image_07905.jpg
# flowers/valid/20/
# flowers/valid/20/image_04940.jpg
# flowers/valid/20/image_04918.jpg
# flowers/valid/20/image_04927.jpg
# flowers/valid/20/image_04913.jpg
# flowers/valid/20/image_04942.jpg
# flowers/valid/20/image_04903.jpg
# flowers/valid/20/image_04920.jpg
# flowers/valid/57/
# flowers/valid/57/image_07255.jpg
# flowers/valid/57/image_07262.jpg
# flowers/valid/57/image_07239.jpg
# flowers/valid/57/image_07247.jpg
# flowers/valid/57/image_07254.jpg
# flowers/valid/57/image_08145.jpg
# flowers/valid/55/
# flowers/valid/55/image_04760.jpg
# flowers/valid/55/image_04722.jpg
# flowers/valid/55/image_04720.jpg
# flowers/valid/55/image_04753.jpg
# flowers/valid/55/image_04696.jpg
# flowers/valid/55/image_04702.jpg
# flowers/valid/55/image_04739.jpg
# flowers/valid/55/image_04734.jpg
# flowers/valid/28/
# flowers/valid/28/image_05272.jpg
# flowers/valid/28/image_05257.jpg
# flowers/valid/28/image_05258.jpg
# flowers/valid/28/image_05265.jpg
# flowers/valid/28/image_05267.jpg
# flowers/valid/50/
# flowers/valid/50/image_06305.jpg
# flowers/valid/50/image_06544.jpg
# flowers/valid/50/image_06331.jpg
# flowers/valid/50/image_06324.jpg
# flowers/valid/50/image_06558.jpg
# flowers/valid/50/image_06550.jpg
# flowers/valid/50/image_06562.jpg
# flowers/valid/50/image_06534.jpg
# flowers/valid/50/image_06311.jpg
# flowers/valid/50/image_06552.jpg
# flowers/valid/50/image_06528.jpg
# flowers/valid/15/
# flowers/valid/15/image_06386.jpg
# flowers/valid/15/image_06354.jpg
# flowers/valid/15/image_06385.jpg
# flowers/valid/15/image_06353.jpg
# flowers/valid/15/image_06389.jpg
# flowers/valid/15/image_06358.jpg
# flowers/valid/15/image_06346.jpg
# flowers/valid/18/
# flowers/valid/18/image_04312.jpg
# flowers/valid/18/image_04290.jpg
# flowers/valid/18/image_04311.jpg
# flowers/valid/18/image_04263.jpg
# flowers/valid/18/image_04278.jpg
# flowers/valid/18/image_04317.jpg
# flowers/valid/18/image_04248.jpg
# flowers/valid/18/image_04261.jpg
# flowers/valid/18/image_04315.jpg
# flowers/valid/18/image_04252.jpg
# flowers/valid/18/image_04299.jpg
# flowers/valid/48/
# flowers/valid/48/image_04690.jpg
# flowers/valid/48/image_04678.jpg
# flowers/valid/48/image_04691.jpg
# flowers/valid/48/image_04688.jpg
# flowers/valid/48/image_04641.jpg
# flowers/valid/48/image_04693.jpg
# flowers/valid/48/image_04652.jpg
# flowers/valid/48/image_04684.jpg
# flowers/valid/48/image_04687.jpg
# flowers/valid/38/
# flowers/valid/38/image_05845.jpg
# flowers/valid/38/image_05829.jpg
# flowers/valid/38/image_05830.jpg
# flowers/valid/38/image_05819.jpg
# flowers/valid/12/
# flowers/valid/12/image_03998.jpg
# flowers/valid/12/image_03997.jpg
# flowers/valid/12/image_04080.jpg
# flowers/valid/12/image_04072.jpg
# flowers/valid/12/image_04013.jpg
# flowers/valid/27/
# flowers/valid/27/image_06868.jpg
# flowers/valid/46/
# flowers/valid/46/image_01029.jpg
# flowers/valid/46/image_00977.jpg
# flowers/valid/46/image_01065.jpg
# flowers/valid/46/image_01086.jpg
# flowers/valid/46/image_01138.jpg
# flowers/valid/46/image_01132.jpg
# flowers/valid/46/image_01100.jpg
# flowers/valid/46/image_01129.jpg
# flowers/valid/46/image_01034.jpg
# flowers/valid/46/image_01030.jpg
# flowers/valid/46/image_00949.jpg
# flowers/valid/46/image_00983.jpg
# flowers/valid/46/image_01142.jpg
# flowers/valid/46/image_01040.jpg
# flowers/valid/46/image_01076.jpg
# flowers/valid/46/image_01050.jpg
# flowers/valid/46/image_01047.jpg
# flowers/valid/46/image_01095.jpg
# flowers/valid/79/
# flowers/valid/79/image_06728.jpg
# flowers/valid/79/image_06718.jpg
# flowers/valid/79/image_06695.jpg
# flowers/valid/79/image_06707.jpg
# flowers/valid/13/
# flowers/valid/13/image_05749.jpg
# flowers/valid/13/image_05759.jpg
# flowers/valid/13/image_05763.jpg
# flowers/valid/13/image_05772.jpg
# flowers/valid/13/image_05783.jpg
# flowers/valid/6/
# flowers/valid/6/image_08105.jpg
# flowers/valid/60/
# flowers/valid/60/image_02959.jpg
# flowers/valid/60/image_03016.jpg
# flowers/valid/60/image_02923.jpg
# flowers/valid/60/image_02948.jpg
# flowers/valid/60/image_02992.jpg
# flowers/valid/60/image_02937.jpg
# flowers/valid/60/image_02936.jpg
# flowers/valid/60/image_02997.jpg
# flowers/valid/60/image_02981.jpg
# flowers/valid/60/image_02974.jpg
# flowers/valid/60/image_02961.jpg
# flowers/valid/60/image_02996.jpg
# flowers/valid/60/image_02928.jpg
# flowers/valid/60/image_03003.jpg
# flowers/valid/54/
# flowers/valid/54/image_05417.jpg
# flowers/valid/54/image_05452.jpg
# flowers/valid/54/image_05451.jpg
# flowers/valid/54/image_05426.jpg
# flowers/valid/54/image_05449.jpg
# flowers/valid/54/image_05415.jpg
# flowers/valid/54/image_05453.jpg
# flowers/valid/54/image_05406.jpg
# flowers/valid/54/image_05411.jpg
# flowers/valid/54/image_05425.jpg
# flowers/valid/1/
# flowers/valid/1/image_06755.jpg
# flowers/valid/1/image_06756.jpg
# flowers/valid/1/image_06749.jpg
# flowers/valid/1/image_06739.jpg
# flowers/valid/1/image_06763.jpg
# flowers/valid/1/image_06765.jpg
# flowers/valid/1/image_06769.jpg
# flowers/valid/1/image_06758.jpg
# flowers/valid/8/
# flowers/valid/8/image_03366.jpg
# flowers/valid/8/image_03342.jpg
# flowers/valid/8/image_03313.jpg
# flowers/valid/8/image_03349.jpg
# flowers/valid/8/image_03330.jpg
# flowers/valid/101/
# flowers/valid/101/image_07963.jpg
# flowers/valid/101/image_07962.jpg
# flowers/valid/101/image_07985.jpg
# flowers/valid/101/image_07951.jpg
# flowers/valid/101/image_07970.jpg
# flowers/valid/73/
# flowers/valid/73/image_00329.jpg
# flowers/valid/73/image_00302.jpg
# flowers/valid/73/image_00424.jpg
# flowers/valid/73/image_00421.jpg
# flowers/valid/73/image_00366.jpg
# flowers/valid/73/image_00442.jpg
# flowers/valid/73/image_00280.jpg
# flowers/valid/73/image_00432.jpg
# flowers/valid/73/image_00354.jpg
# flowers/valid/73/image_00436.jpg
# flowers/valid/73/image_00415.jpg
# flowers/valid/73/image_00356.jpg
# flowers/valid/73/image_00352.jpg
# flowers/valid/73/image_00402.jpg
# flowers/valid/73/image_00275.jpg
# flowers/valid/73/image_00440.jpg
# flowers/valid/73/image_00381.jpg
# flowers/valid/73/image_00295.jpg
# flowers/valid/73/image_00378.jpg
# flowers/valid/81/
# flowers/valid/81/image_00859.jpg
# flowers/valid/81/image_00895.jpg
# flowers/valid/81/image_00892.jpg
# flowers/valid/81/image_00914.jpg
# flowers/valid/81/image_00853.jpg
# flowers/valid/81/image_00809.jpg
# flowers/valid/81/image_00820.jpg
# flowers/valid/81/image_00893.jpg
# flowers/valid/81/image_00903.jpg
# flowers/valid/81/image_00909.jpg
# flowers/valid/81/image_00784.jpg
# flowers/valid/81/image_00848.jpg
# flowers/valid/81/image_00904.jpg
# flowers/valid/81/image_00863.jpg
# flowers/valid/81/image_00920.jpg
# flowers/valid/81/image_00860.jpg
# flowers/valid/81/image_00896.jpg
# flowers/valid/81/image_00919.jpg
# flowers/valid/62/
# flowers/valid/62/image_07271.jpg
# flowers/valid/62/image_08171.jpg
# flowers/valid/62/image_08155.jpg
# flowers/valid/89/
# flowers/valid/89/image_00627.jpg
# flowers/valid/89/image_00640.jpg
# flowers/valid/89/image_00746.jpg
# flowers/valid/89/image_00652.jpg
# flowers/valid/89/image_00741.jpg
# flowers/valid/89/image_00730.jpg
# flowers/valid/89/image_00624.jpg
# flowers/valid/89/image_00763.jpg
# flowers/valid/89/image_00752.jpg
# flowers/valid/89/image_00692.jpg
# flowers/valid/89/image_00696.jpg
# flowers/valid/89/image_00749.jpg
# flowers/valid/89/image_00759.jpg
# flowers/valid/89/image_00623.jpg
# flowers/valid/89/image_00764.jpg
# flowers/valid/89/image_00691.jpg
# flowers/valid/99/
# flowers/valid/99/image_07875.jpg
# flowers/valid/99/image_07862.jpg
# flowers/valid/99/image_07873.jpg
# flowers/valid/99/image_07860.jpg
# flowers/valid/99/image_08063.jpg
# flowers/valid/99/image_07869.jpg
# flowers/valid/24/
# flowers/valid/24/image_06818.jpg
# flowers/valid/24/image_06814.jpg
# flowers/valid/24/image_06836.jpg
# flowers/valid/24/image_06847.jpg
# flowers/valid/24/image_06819.jpg
# flowers/valid/75/
# flowers/valid/75/image_02100.jpg
# flowers/valid/75/image_02178.jpg
# flowers/valid/75/image_02182.jpg
# flowers/valid/75/image_02152.jpg
# flowers/valid/75/image_02081.jpg
# flowers/valid/75/image_02141.jpg
# flowers/valid/75/image_02104.jpg
# flowers/valid/75/image_02147.jpg
# flowers/valid/75/image_02155.jpg
# flowers/valid/75/image_02133.jpg
# flowers/valid/75/image_02130.jpg
# flowers/valid/75/image_02074.jpg
# flowers/valid/84/
# flowers/valid/84/image_02621.jpg
# flowers/valid/84/image_02591.jpg
# flowers/valid/84/image_02610.jpg
# flowers/valid/84/image_02574.jpg
# flowers/valid/84/image_02582.jpg
# flowers/valid/84/image_02637.jpg
# flowers/valid/84/image_02598.jpg
# flowers/valid/84/image_02604.jpg
# flowers/valid/84/image_02635.jpg
# flowers/valid/84/image_02567.jpg
# flowers/valid/44/
# flowers/valid/44/image_01569.jpg
# flowers/valid/44/image_01573.jpg
# flowers/valid/44/image_01579.jpg
# flowers/valid/44/image_01494.jpg
# flowers/valid/44/image_01491.jpg
# flowers/valid/44/image_01570.jpg
# flowers/valid/44/image_01500.jpg
# flowers/valid/44/image_01510.jpg
# flowers/valid/44/image_01540.jpg
# flowers/valid/30/
# flowers/valid/30/image_03469.jpg
# flowers/valid/30/image_03544.jpg
# flowers/valid/30/image_03487.jpg
# flowers/valid/30/image_03467.jpg
# flowers/valid/30/image_03530.jpg
# flowers/valid/30/image_03485.jpg
# flowers/valid/30/image_03531.jpg
# flowers/valid/30/image_03471.jpg
# flowers/valid/30/image_03464.jpg
# flowers/valid/30/image_03475.jpg
# predict.py
# train.py
# workspace-utils.py
